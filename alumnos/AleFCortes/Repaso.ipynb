# %% [markdown]
# # 0-intro_ipython.ipynb

# %%
print "Hola como estas?"
# Out:
# Hola como estas?

# %%
?

# %%
from IPython.display import display

# %%
from IPython.display import Image

# %%
i = Image(filename = './imagenes/ipython_logo.png')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-19-58f46996fdfb> in <module>()
# ----> 1 i = Image(filename = './imagenes/ipython_logo.png')
#
# C:\Anaconda\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina)
#     644         self.height = height
#     645         self.retina = retina
# --> 646         super(Image, self).__init__(data=data, url=url, filename=filename)
#     647
#     648         if retina:
#
# C:\Anaconda\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename)
#     334         self.filename = None if filename is None else unicode_type(filename)
#     335
# --> 336         self.reload()
#     337         self._check_data()
#     338
#
# C:\Anaconda\lib\site-packages\IPython\core\display.pyc in reload(self)
# ...

# %%
i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-372e25f23b5a> in <module>()
# ----> 1 i
#
# NameError: name 'i' is not defined

# %%
display(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-038757e47060> in <module>()
# ----> 1 display(i)
#
# NameError: name 'i' is not defined

# %%
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
from IPython.display import HTML

# %%
from IPython.display import Javascript

# %%
from IPython.display import Audio

# %%
Audio(url="http://en.wikipedia.org/wiki/File:Edison_cylinder_Lost_Chord.ogg")
# Out:
#                 <audio controls="controls" >
#                     <source src="http://en.wikipedia.org/wiki/File:Edison_cylinder_Lost_Chord.ogg" type="None" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("iTT85DOwEXY")
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/iTT85DOwEXY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.html.widgets import interact,fixed
from IPython.html import widgets

# %%
def foo(x):
    print x

# %%
foo(5)
# Out:
# 5

# %%
interact (foo, x =10);
# Out:
# 24

# %%
interact (foo, x = True);
# Out:
# True

# %%
interact ( foo, x = u"Hola ¿Cómo estas?");
# Out:
# Hola ¿Cómo estas?

# %%
interact (foo , x = ("hola", "adios"));
# Out:
# adios

# %%
interact (foo, x={"hola": 1, "adios" : 2});
# Out:
# 1

# %%
def bar(p,q):
    print p,q

# %%
bar (10,20)
# Out:
# 10 20

# %%
interact ( bar, p=5, q= fixed (20));
# Out:
# 5 20

# %%
# !pwd
# Out:
# "pwd" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# !whoami
# Out:
# wall-e\fofa cort‚s

# %%
files = !ls
print "Los archivos en esta carpeta son:"
print files
# Out:
# Los archivos en esta carpeta son:
# ['NumPy_tarea.ipynb', 'Repaso.ipynb', 'cartesianas_a_esfericas.ipynb', 'hola.txt', 'notas', 'project_euler', 'tareas', 'transformacion.py', 'utilerias2.py']

# %%
# %magic

# %%
# %timeit range(10)
# Out:
# 1000000 loops, best of 3: 429 ns per loop

# %%
# %%file util.py
def sort_string (s):
        s= sorted (s)
        print ''.join(s)
# Out:
# Overwriting util.py

# %%
# !cat util.py
# Out:
# def sort_string (s):
#         s= sorted (s)
#         print ''.join(s)

# %%
# %load util.py

# %%
def sort_string (s):
        s= sorted (s)
        print ''.join(s)

# %%
from util import sort_string
sort_string("GOAL")
# Out:
# AGLO

# %%
# !rm $PWD/util.py
# Out:
# rm: cannot remove `$PWD/util.py': No such file or directory

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,2*np.pi, 300)
y = np.cos (x**3)
plt.plot(x,y)
plt.title(u"¡Hola desde plot!");

# %% [markdown]
# # 1-python_tour.ipynb

# %%
str?

# %%
#str.#presionar tab

# %%
x=1

# %%
x
# Out:
# 1

# %%
print x
# Out:
# 1

# %%
a,b =3, 4
print "EL valor de a es: " , a
print "El valor de b es: ", b
# Out:
# EL valor de a es:  3
# El valor de b es:  4

# %%
x = 3
x
# Out:
# 3

# %%
y=3.5
y
# Out:
# 3.5

# %%
z = 3 + 5j
z
# Out:
# (3+5j)

# %%
a=True
a
# Out:
# True

# %%
x = 1.2e34
x
# Out:
# 1.2e+34

# %%
x = 1e-12 + 3.56e4j
x
# Out:
# (1e-12+35600j)

# %%
cadena = u"Esto es una cadena de texto con acentos y otros símbolos UTF-8 ¿?¡!"
cadena
# Out:
# u'Esto es una cadena de texto con acentos y otros s\xedmbolos UTF-8 \xbf?\xa1!'

# %%
print cadena
# Out:
# Esto es una cadena de texto con acentos y otros símbolos UTF-8 ¿?¡!

# %%
print cadena.lower()
# Out:
# esto es una cadena de texto con acentos y otros símbolos utf-8 ¿?¡!

# %%
x= int (2)
y = float (3)
z = complex (1+2j)
a = str("Hola")

# %%
print x,y,z,a
# Out:
# 2 3.0 (1+2j) Hola

# %%
x=3
y=4+3j

# %%
x+y
# Out:
# (7+3j)

# %%
x-y
# Out:
# (-1-3j)

# %%
x*y
# Out:
# (12+9j)

# %%
x**y
# Out:
# (-80.03836209851747-12.44429960209101j)

# %%
x/y
# Out:
# (0.48-0.36j)

# %%
y%x
# Out:
# (1+3j)

# %%
a = 3
b = "hola"

# %%
a +b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-9be4ae1b5a84> in <module>()
# ----> 1 a +b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a) + b
# Out:
# '3hola'

# %%
b+b
# Out:
# 'holahola'

# %%
a*b
# Out:
# 'holaholahola'

# %%
a,b,c = 1.0, 2.0, 3.0
print a
print b
print c
# Out:
# 1.0
# 2.0
# 3.0

# %%
a + b/c
# Out:
# 1.6666666666666665

# %%
(a+b)/c
# Out:
# 1.0

# %%
x=0
x+=1

# %%
print x
# Out:
# 1

# %%
x-=2

# %%
print x
# Out:
# -1

# %%
x *= 3.14
print x
# Out:
# -3.14

# %%
x /=5*a
print x
# Out:
# -0.628

# %%
if  x>3:
    print "esto no se deberia impirimir"
    print "Nota que es muy peligroso hacer esto con flotantes...."

# %%
x=5

# %%
if x>3:
    print "esto si se deberia de imprimir"
# Out:
# esto si se deberia de imprimir

# %%
x == 1
# Out:
# False

# %%
x>1
# Out:
# True

# %%
x<1
# Out:
# False

# %%
x>=5
# Out:
# True

# %%
x!=1
# Out:
# True

# %%
x>10 or x<=5
# Out:
# True

# %%
x>10 and x<=5
# Out:
# False

# %%
print x
# Out:
# 5

# %%
if x>= 5 and x<10:
    print u"¡hola!"
else:
    print u"nunca me verás"
# Out:
# ¡hola!

# %%
for i in (1,2,3,4,5):
    print i
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for x in u"Hola Como estás?":
    print x
# Out:
# H
# o
# l
# a
#
# C
# o
# m
# o
#
# e
# s
# t
# á
# s
# ?

# %%
i =1
while i > 0 and i<=5:
    print i
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in xrange (3,10,2):
    print i
# Out:
# 3
# 5
# 7
# 9

# %%
for i in range (1,1001):
    i = i +(1/i)**2
print i
# Out:
# 1000

# %%
a_list = [1,2,3,4,5]
a_list
# Out:
# [1, 2, 3, 4, 5]

# %%
another_list = [1,1.3,4.5,2+1j,[1,2]]
another_list
# Out:
# [1, 1.3, 4.5, (2+1j), [1, 2]]

# %%
a_list[3]
# Out:
# 4

# %%
another_list[3]
# Out:
# (2+1j)

# %%
another_list[4]
# Out:
# [1, 2]

# %%
a_list[-1]
# Out:
# 5

# %%
a_list[1:]
# Out:
# [2, 3, 4, 5]

# %%
a_list[2:4]
# Out:
# [3, 4]

# %%
a_list[:4]
# Out:
# [1, 2, 3, 4]

# %%
n=5

# %%
a_list.append(n)

# %%
a_list
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
a_list.pop()
# Out:
# 5

# %%
a_list
# Out:
# [1, 2, 3, 4, 5]

# %%
a_list.append(3)
a_list[1] = 3
a_list.append(5)

# %%
a_list.remove?

# %%
a_list
# Out:
# [1, 3, 3, 4, 5, 3, 5]

# %%
a_list.remove(3)
a_list
# Out:
# [1, 3, 4, 5, 3, 5]

# %%
a_list.remove(5)
a_list
# Out:
# [1, 3, 4, 3, 5]

# %%
empty_list = []
empty_list
# Out:
# []

# %%
for element in a_list:
    print element
# Out:
# 1
# 3
# 4
# 3
# 5

# %%
for r in range(5):
    print r
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
S = [x**2 for x in range (10)]
V = [2**x for x in range (13)]
M = [x for x in S if x%2 != 0]
print S
print V
print M
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]
# [1, 9, 25, 49, 81]

# %%
palabras = 'Anita lava la tina'.split()
print palabras
transformacion = [[w.upper(), w.lower(), len(w)] for w in palabras]
for t in transformacion:
    print t
# Out:
# ['Anita', 'lava', 'la', 'tina']
# ['ANITA', 'anita', 5]
# ['LAVA', 'lava', 4]
# ['LA', 'la', 2]
# ['TINA', 'tina', 4]

# %%
transformacion
# Out:
# [['ANITA', 'anita', 5],
#  ['LAVA', 'lava', 4],
#  ['LA', 'la', 2],
#  ['TINA', 'tina', 4]]

# %%
n=25
[(x,y,z) for x in range(1,n)for y in range(x,n)for z in range(y,n) if x*x + y*y ==z*z ]
# Out:
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (8, 15, 17), (9, 12, 15), (12, 16, 20)]

# %%
diccionario = {'a':1, 'b':2,'coral':'amarillo'}

# %%
diccionario['a']
# Out:
# 1

# %%
diccionario['coral']
# Out:
# 'amarillo'

# %%
from math import sqrt,atan
def polar (x,y):
    """
    x,y,z son un par ordenado
    """
    r = sqrt(x**2 + y**2)
    theta = atan(y/x)
    print r, theta

# %%
polar?

# %%
polar??

# %%
r, theta = polar (3,4)
print "La coordenada r es: ", r
print "El ángulo theta es: ", theta
# Out:
# La coordenada r es:  5.0
# El ángulo theta es:  0.785398163397

# %%
interact(polar,x=2,y=3);
# Out:
# 3.60555127546 0.785398163397

# %% [markdown]
# # 0-computación-numérica.ipynb

# %% [markdown]
# El tipo int se representa en 4-bytes, es decir 32 bits. El nivel máximo a nivle CPU está dado por:

# %%
2**32
# Out:
# 4294967296L

# %% [markdown]
# Pero como queremos represntar los positivos y negativos:

# %%
[-2**32/2, 2**32/2]
# Out:
# [-2147483648L, 2147483648L]

# %% [markdown]
# valor exacto del limite de mi computadora:

# %%
import sys
sys.maxint
# Out:
# 2147483647

# %% [markdown]
# python puede utilizar enteros sin límite de precisión: long integers

# %%
x=1
print x
type(x)
# Out:
# 1
# int

# %%
x=1L
print x
type(x)
# Out:
# 1
# long

# %%
x = 10000000
type(x)
# Out:
# int

# %%
type(x*x*x)
# Out:
# long

# %%
type(sys.maxint)
# Out:
# int

# %%
type(sys.maxint +1)
# Out:
# long

# %% [markdown]
# Para obtener la representación binaria de un número

# %%
bin(123)
# Out:
# '0b1111011'

# %%
for i in xrange(0,5):
    print "%d \t %s" % (i,bin(i))
# Out:
# 0 	 0b0
# 1 	 0b1
# 2 	 0b10
# 3 	 0b11
# 4 	 0b100

# %% [markdown]
# padding para agregar 0's a los que les falta

# %% [markdown]
# ### Flotantes

# %% [markdown]
# Recordemos que los decimales (_flotantes_) que son **racionales** ($\mathbb{Q}$) se pueden representar como la suma de fracciones en base $10$:

# %% [markdown]
# `0.125` $\equiv \frac{1}{10} + \frac{2}{100} + \frac{5}{1000}$

# %% [markdown]
# También queremos representar los irracionales pero conduce a un perdida de ***precisión***

# %% [markdown]
# En base $2$ los flotantes se representan igual:

# %% [markdown]
# `0.001`$\equiv \frac{0}{2} + \frac{0}{4} + \frac{1}{8}$

# %%
bin(0.125)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-d9ebbdf47ef4> in <module>()
# ----> 1 bin(0.125)
#
# TypeError: 'float' object cannot be interpreted as an index

# %%
float.hex(0.125)
# Out:
# '0x1.0000000000000p-3'

# %% [markdown]
# ###### Error de precisión

# %%
0.1
# Out:
# 0.1

# %%
0.1+0.2
# Out:
# 0.30000000000000004

# %%
round(2.675,2) # redondear a dos decimales
# Out:
# 2.67

# %%
from decimal import Decimal
Decimal(2.675)
# Out:
# Decimal('2.67499999999999982236431605997495353221893310546875')

# %%
Decimal(0.1)
# Out:
# Decimal('0.1000000000000000055511151231257827021181583404541015625')

# %% [markdown]
# otro problema de perdida de precisión es:

# %%
suma=0.0

# %%
for x in range(10):
    suma += 0.1
suma
# Out:
# 2.0000000000000004

# %%
x = 0.0
while not x==1.0:
    x = x + 0.1
    print ("x = %19.17g" % (x))
# Out:
# x = 0.10000000000000001
# x = 0.20000000000000001
# x = 0.30000000000000004
# x = 0.40000000000000002
# x =                 0.5
# x = 0.59999999999999998
# x = 0.69999999999999996
# x = 0.79999999999999993
# x = 0.89999999999999991
# x = 0.99999999999999989
# x =  1.0999999999999999
# x =                 1.2
# x =                 1.3
# x =  1.4000000000000001
# x =  1.5000000000000002
# x =  1.6000000000000003
# x =  1.7000000000000004
# x =  1.8000000000000005
# x =  1.9000000000000006
# x =  2.0000000000000004
# x =  2.1000000000000005
# x =  2.2000000000000006
# x =  2.3000000000000007
# x =  2.4000000000000008
# x =  2.5000000000000009
# x =   2.600000000000001
# x =  2.7000000000000011
# x =  2.8000000000000012
# x =  2.9000000000000012
# x =  3.0000000000000013
# x =  3.1000000000000014
# x =  3.2000000000000015
# x =  3.3000000000000016
# x =  3.4000000000000017
# x =  3.5000000000000018
# x =  3.6000000000000019
# x =   3.700000000000002
# x =   3.800000000000002
# ...
